# %%
# This is a comment - Python ignores it
print("Hello, Smart Farming!")

# Simple calculation
hectares = 6
yield_per_hectare = 2500
total_yield = hectares * yield_per_hectare
print(f"Total expected yield: {total_yield} kg")
# Out:
# Hello, Smart Farming!
# Total expected yield: 15000 kg
