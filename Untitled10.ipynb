# %%
 Crops=["rice","ragi","maize", "millets"]
Stages=["seedling", "vegitative", "maturity", "harvesting"]

matrix = []

for crop in range(4):
    row = []
    for stage in range(4):
        dose = (crop + 1) * (stage + 1) * 5
        row.append((i+1)×()
    matrix.append(row)

Print("  ", stage)
for row in matrix:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4092260340.py in <cell line: 0>()
#      11    matrix.append(row)
#      12
# ---> 13 Print("  ", stage)
#      14 for row in matrix:
#      15    print(row)
#
# NameError: name 'Print' is not defined

# %%
crops = ["Wheat", "Rice", "Maize", "Barley"]
stages = ["Seedling", "Vegetative", "Flowering", "Maturity"]

matrix = []

for i in range(4):
    row = []
    for j in range(4):
        row.append((i + 1) * (j + 1) * 10)
    matrix.append(row)

print("matrix", stages)
for i in range(4):
    print(crops[i], matrix[i])
# Out:
# matrix ['Seedling', 'Vegetative', 'Flowering', 'Maturity']
# Wheat [10, 20, 30, 40]
# Rice [20, 40, 60, 80]
# Maize [30, 60, 90, 120]
# Barley [40, 80, 120, 160]
