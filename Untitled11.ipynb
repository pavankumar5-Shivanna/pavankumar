# %%
Crops=["rice","maize", "ragi", "wheat"]
matrix = []

for i in range(4):
    row = []
    for j in range(4):
        dosage = (i + 1) * (j + 1) * 5
        row.append(dosage)
    matrix.append(row)

for row in matrix:
    print(row)
# Out:
# [5, 10, 15, 20]
# [10, 20, 30, 40]
# [15, 30, 45, 60]
# [20, 40, 60, 80]
